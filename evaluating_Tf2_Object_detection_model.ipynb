# %% [markdown]
# # Grape object detection - evaluation

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !pip install tf-models-official
# !pip install tf-slim
# !pip install lvis

# %%
# !pip install pycocotools

# %%
# %cd /content/drive/My Drive/Prova_pratica-processo_seletivo-pesquisadorI/Object_detection/models/research/object_detection

# %%
###Eval
# !python model_main_tf2.py --model_dir=training --pipeline_config_path=training/faster_rcnn_resnet152_v1_1024x1024_coco17_tpu-8.config --checkpoint_dir=training

# %%
# %load_ext tensorboard 
# %tensorboard --logdir=training
